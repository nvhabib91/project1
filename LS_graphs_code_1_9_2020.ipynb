# %%
import pandas as pd
import numpy as np
import requests
import json
import matplotlib.pyplot as plt
import os
import csv
# %matplotlib inline

# %%
firecsv = pd.read_csv('fire_clean.csv')

# %%
firecsv
# Out:
#             FOD_ID SOURCE_SYSTEM SOURCE_REPORTING_UNIT_NAME  FIRE_YEAR  \
# 0                1   FS-FIRESTAT     Plumas National Forest       2005
# 1                2   FS-FIRESTAT   Eldorado National Forest       2004
# 2                3   FS-FIRESTAT   Eldorado National Forest       2004
# 3                4   FS-FIRESTAT   Eldorado National Forest       2004
# 4                5   FS-FIRESTAT   Eldorado National Forest       2004
# ...            ...           ...                        ...        ...
# 1880460  300348363      ST-CACDF        Shasta-Trinity Unit       2015
# 1880461  300348373      ST-CACDF    Tuolumne-Calaveras Unit       2015
# 1880462  300348375      ST-CACDF    Tuolumne-Calaveras Unit       2015
# 1880463  300348377      ST-CACDF    Tuolumne-Calaveras Unit       2015
# 1880464  300348399      ST-CACDF  CDF - San Bernardino Unit       2015
#
#           STAT_CAUSE_DESCR  FIRE_SIZE FIRE_SIZE_CLASS   LATITUDE   LONGITUDE  \
# 0            Miscellaneous       0.10               A  40.036944 -121.005833
# 1                Lightning       0.25               A  38.933056 -120.404444
# 2           Debris Burning       0.10               A  38.984167 -120.735556
# 3                Lightning       0.10               A  38.559167 -119.913333
# 4                Lightning       0.10               A  38.559167 -119.933056
# ...                    ...        ...             ...        ...         ...
# 1880460  Missing/Undefined       0.01               A  40.481637 -122.389375
# 1880461      Miscellaneous       0.20               A  37.617619 -120.938570
# 1880462  Missing/Undefined       0.10               A  37.617619 -120.938570
# 1880463  Missing/Undefined       2.00               B  37.672235 -120.898356
# 1880464      Miscellaneous       0.10               A  34.263217 -116.830950
#
#         STATE
# 0          CA
# 1          CA
# 2          CA
# 3          CA
# 4          CA
# ...       ...
# 1880460    CA
# 1880461    CA
# 1880462    CA
# 1880463    CA
# 1880464    CA
#
# [1880465 rows x 10 columns]

# %%
pivoted_table = firecsv.pivot_table(index="STATE", values="FIRE_SIZE", aggfunc="sum").rename_axis(None, axis=1).sort_values(by=["FIRE_SIZE"]).reset_index()

# %%
pivoted_table["FIRE_SIZE"] = pivoted_table["FIRE_SIZE"].astype("int64")

# %%
pivoted_table
# Out:
#    STATE  FIRE_SIZE
# 0     DC         32
# 1     RI        562
# 2     VT       1556
# 3     NH       3862
# 4     DE       4833
# 5     MA       6124
# 6     CT      11243
# 7     IN      17322
# 8     IL      22807
# 9     OH      23933
# 10    ME      24555
# 11    PA      54730
# 12    MD      67279
# 13    IA      71491
# 14    WI      88675
# 15    NY      93771
# 16    NJ     131963
# 17    PR     138688
# 18    MI     140229
# 19    HI     252761
# 20    VA     341645
# 21    ND     412607
# 22    MO     459525
# 23    TN     486652
# 24    AR     508911
# 25    SC     541666
# 26    WV     576631
# 27    LA     661023
# 28    NC     730521
# 29    AL     920545
# 30    KS     922613
# 31    NE     967398
# 32    KY    1014890
# 33    MS    1135483
# 34    MN    1210605
# 35    SD    1570865
# 36    GA    1589959
# 37    CO    1842309
# 38    WY    2401470
# 39    OK    3232490
# 40    UT    4114926
# 41    FL    4436748
# 42    WA    4782218
# 43    AZ    5576680
# 44    MT    6279526
# 45    NM    6380041
# 46    OR    8412801
# 47    NV    9015855
# 48    TX    9786218
# 49    CA   12745858
# 50    ID   13684334
# 51    AK   32233094

# %%
# Pie Chart grouping
# States > 5 million acres burned
top_states = pivoted_table.loc[((pivoted_table["FIRE_SIZE"]) >= 7000000)]
# States 1-5 million acres burned
middle_states = pivoted_table.loc[((pivoted_table["FIRE_SIZE"]) >= 1000000) & ((pivoted_table["FIRE_SIZE"]) < 7000000)]
# States 100k to 999k acres burned
less_states = pivoted_table.loc[((pivoted_table["FIRE_SIZE"]) >= 100000) & ((pivoted_table["FIRE_SIZE"]) <= 999999)]
# All other states
other_states = pivoted_table.loc[((pivoted_table["FIRE_SIZE"]) <= 99999)]

# math_passers = student_data.loc[student_data["math_score"] >= 70]
# math_passers_grp = math_passers.groupby(["school_name"], as_index=False).count()
# math_df = pd.DataFrame(math_passers_grp["math_score"]).reset_index()

# %%
middle_sum = middle_states["FIRE_SIZE"].sum()
less_states = less_states["FIRE_SIZE"].sum()
other_sum = other_states["FIRE_SIZE"].sum()

# %%
pie_data = pd.DataFrame(top_states)
pie_data
# Out:
#    STATE  FIRE_SIZE
# 46    OR    8412801
# 47    NV    9015855
# 48    TX    9786218
# 49    CA   12745858
# 50    ID   13684334
# 51    AK   32233094

# %%
middle_list = {'STATE':'1-5 mill', 'FIRE_SIZE':middle_sum}
pie_data = pie_data.append(middle_list, ignore_index=True)

# %%
less_list = {'STATE':'100k to 999k', 'FIRE_SIZE':less_sum}
pie_data = pie_data.append(less_list, ignore_index=True)

# %%
other_list= {'STATE':'Under 99k', 'FIRE_SIZE':other_sum}
pie_data = pie_data.append(other_list, ignore_index=True)

# %%
pie_data
# Out:
#           STATE  FIRE_SIZE
# 0            OR    8412801
# 1            NV    9015855
# 2            TX    9786218
# 3            CA   12745858
# 4            ID   13684334
# 5            AK   32233094
# 6      1-5 mill   45568210
# 7  100k to 999k    8193378
# 8     Under 99k     492775

# %%
sizes = pie_data["FIRE_SIZE"]
labels = pie_data["STATE"]

# %%
# 1. Total fire size per significant statea (pie chart)
plt.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True, startangle=140, radius=2)
plt.legend(loc=2, bbox_to_anchor=(1.5, -0.1))
figure_title = "Total Fire Sizes Per State"
plt.title("Total Fire Sizes Per State", x=1.75, y=-0.1, fontsize="16")
plt.tight_layout
plt.savefig("total_fire_sizes_per_state.png")

# %%
# 2. Average Fire Size Per State 
count_table = firecsv.pivot_table(index="STATE", values="FIRE_SIZE", aggfunc="mean").rename_axis(None, axis=1).sort_values(by=["FIRE_SIZE"]).reset_index()
count_table
# Out:
#    STATE    FIRE_SIZE
# 0     DC     0.492424
# 1     NY     1.159540
# 2     RI     1.171688
# 3     NH     1.575044
# 4     ME     1.867349
# 5     CT     2.259508
# 6     MA     2.332342
# 7     WI     2.783192
# 8     VT     3.413346
# 9     NJ     5.085496
# 10    PR     6.280894
# 11    PA     6.282227
# 12    NC     6.564892
# 13    SC     6.661331
# 14    OH     6.879521
# 15    IN     8.256859
# 16    GA     9.415452
# 17    IL     9.801253
# 18    MI    13.352641
# 19    AL    13.828230
# 20    MS    14.331488
# 21    TN    15.620864
# 22    VA    15.648139
# 23    AR    16.072761
# 24    IA    17.293654
# 25    MD    18.575243
# 26    LA    22.024586
# 27    HI    25.544315
# 28    MO    25.596042
# 29    WV    26.249877
# 30    MN    27.041154
# 31    ND    27.143427
# 32    DE    28.266959
# 33    KY    37.465052
# 34    FL    49.154653
# 35    SD    50.733637
# 36    CO    53.936502
# 37    CA    67.242725
# 38    TX    68.906840
# 39    OK    74.758674
# 40    AZ    77.901837
# 41    KS   120.241601
# 42    NE   121.334348
# 43    UT   133.927628
# 44    OR   137.716104
# 45    WA   142.697410
# 46    MT   154.034541
# 47    WY   169.523555
# 48    NM   170.234318
# 49    ID   372.890482
# 50    NV   531.720650
# 51    AK  2509.779198

# %%
count_table["FIRE_SIZE"] = count_table["FIRE_SIZE"].astype("int64")

# %%
# Bar Chart grouping
# # States with biggest size of fires
top_mean = count_table.loc[((count_table["FIRE_SIZE"]) >= 100)]
# States that have slightly smaller size fires
mid_mean = count_table.loc[((count_table["FIRE_SIZE"]) >= 20) & ((count_table["FIRE_SIZE"]) <= 80)]
# # All other states
other_states = count_table.loc[((count_table["FIRE_SIZE"]) <= 24)]

# %%
other_states
# Out:
#    STATE  FIRE_SIZE
# 0     DC          0
# 1     NY          1
# 2     RI          1
# 3     NH          1
# 4     ME          1
# 5     CT          2
# 6     MA          2
# 7     WI          2
# 8     VT          3
# 9     NJ          5
# 10    PR          6
# 11    PA          6
# 12    NC          6
# 13    SC          6
# 14    OH          6
# 15    IN          8
# 16    GA          9
# 17    IL          9
# 18    MI         13
# 19    AL         13
# 20    MS         14
# 21    TN         15
# 22    VA         15
# 23    AR         16
# 24    IA         17
# 25    MD         18
# 26    LA         22

# %%
mid_mean_mean = mid_mean.mean()

# %%
mid_mean_mean
# Out:
# FIRE_SIZE    43.666667
# dtype: float64

# %%
other_states_mean = other_states.mean()
other_states_mean
# Out:
# FIRE_SIZE    8.037037
# dtype: float64

# %%
mean_df = {"STATE": ["25-70 acres", ">22 acres"], "FIRE_SIZE":[43.66, 8.03]}
mean_df = pd.DataFrame(mean_df)
mean_df
# Out:
#          STATE  FIRE_SIZE
# 0  25-70 acres      43.66
# 1    >22 acres       8.03

# %%
fig, ax = plt.subplots(figsize=(10,4))
bar_x = top_mean["STATE"]
bar_x2 = mean_df["STATE"]
bar_x3 = mean_df["STATE"]
bar_y = top_mean["FIRE_SIZE"]
bar_y2 = mean_df["FIRE_SIZE"]
bar_y3 = mean_df["FIRE_SIZE"]
z = 1
bar_pass = ax.bar(bar_x, bar_y, z, color="red", edgecolor="black")
bar_pass = ax.bar(bar_x2, bar_y2, z, color="red", edgecolor="black")
bar_pass = ax.bar(bar_x3, bar_y2, z, color="red", edgecolor="black")
plt.xticks(rotation=90)
ax.set_title("Average Fire Size Acre Per State")
ax.set_xlabel("STATES")
ax.set_ylabel("Average Acre")
ax.grid(axis="y", alpha=0.5)
plt.savefig("avg_fire_size_per_state.png")

# %%
cluster_data = firecsv.pivot_table(index="STATE", columns="FIRE_YEAR", values="FIRE_SIZE", aggfunc="sum").rename_axis(None, axis=1).reset_index()
cluster_data = pd.DataFrame(cluster_data).set_index("STATE").fillna(0)
cluster_data
# Out:
#              1992        1993        1994        1995        1996        1997  \
# STATE
# AK     142717.400  687191.500  261964.900   43962.100  598797.200  2026204.50
# AL       1253.200    2336.800   34664.400   38896.600   47683.200    22055.40
# AR       1478.500    1760.200    2303.900    5190.400    5286.800    11442.40
# AZ      42593.650  205567.020  224199.735  262152.830  187400.565    13356.90
# CA     296439.800  321495.300  407944.700  216068.700  707110.500   324566.30
# CO       7451.900   35555.300   70760.600   20043.700   70040.500     6038.20
# CT        466.050     401.100     943.150     427.400      66.450      600.35
# DC          0.400       9.800       5.100       0.600       0.000        0.30
# DE        124.000       1.000      96.000    2014.400       0.000       24.60
# FL      95279.700   79755.200  103085.400   56682.700  107511.500   133163.90
# GA      27016.370   40515.590   25013.890   24460.520   37975.890    21908.14
# HI      11161.300    2562.000      78.600    1027.500     380.300       52.00
# IA         85.300      30.700     105.400      57.400    1026.400       93.00
# ID     684658.900    7978.200  729029.600  268681.300  896659.900    42902.40
# IL        235.400      29.800     383.700     993.200     149.800       13.70
# IN        247.300     464.300     577.900     881.400     495.000       83.00
# KS        251.600    1809.300   84460.100    4537.900  147570.400    11410.40
# KY        604.500     843.100    4660.600    5863.600    1117.800    11612.70
# LA      25129.100    8066.800    2520.600    7277.900    8254.100    21649.00
# MA          5.400       1.500       0.100       8.700       2.200        5.40
# MD       1160.300    1672.900     786.900    1304.400     312.100      181.70
# ME       4399.300    1413.150    2012.690    1137.080     403.350      896.77
# MI       2987.400    1008.000    6704.200    4872.300    2921.700      552.10
# MN      30182.130   19087.710   37150.320   46067.310   29633.940    20708.74
# MO      28716.000   14997.300   36249.400   50196.400    8538.300    23939.70
# MS      60830.100   54108.300   54478.500   68013.800  101707.700    32355.60
# MT      38591.720   12598.410  265689.350   25183.950  208840.450    11343.13
# NC      27489.100   26461.200   44936.200   23404.300   17358.000    17412.00
# ND       6373.900    3923.900   11743.300    2047.600    4801.800     6203.80
# NE       1227.100     173.500    6869.500   55757.800    8278.300    18129.50
# NH        164.671     166.663     207.234     309.042      95.734      108.17
# NJ      16603.650     922.700    2725.850   22962.146     929.600     4767.80
# NM      99202.450  302344.040  416646.720  139862.350  171645.960   169966.50
# NV      92345.800   53979.900  196057.800  120031.400  627484.000    41857.40
# NY       2334.400    1126.300    1154.600    9167.450     417.300     1421.80
# OH        101.700      42.700     125.700     292.300      70.300       41.50
# OK      47575.100   69803.500   75164.200   94478.900  207500.000    19627.60
# OR     117437.360   13843.280  276054.320   61282.490  590641.840    24603.94
# PA         59.700      40.800      66.500      51.200      18.900      107.70
# PR        127.000     163.000    1000.000       0.000     502.000       82.80
# RI          0.000       0.000      25.000       0.000       0.000        0.00
# SC      31202.800   34284.700   30354.100   17794.800   28609.600    25238.50
# WI        2796.800  9.138070e+03    2823.736000  2.721440e+03
# WV       16745.520  9.714030e+03   13638.510000  1.725137e+04
# WY      482305.460  5.432180e+04    7725.890000  3.682122e+04
#
# [52 rows x 24 columns]

# %%
# Data filtered for 2010-2015 to reduce size
# clustered_years = cluster_data.drop(cluster_data.iloc[:, 2:4], axis=1).set_index("STATE").fillna(0)
# clustered_years = cluster_data.drop(cluster_data.iloc[:, 1:8], axis=1).set_index("STATE").fillna(0)

# %%
# Data filtered for the top states to reduce size
cluster_filter = cluster_data.loc[["CA", "ID", "AK"]]

# %%
cluster_filter = pd.DataFrame(cluster_filter).reset_index()
cluster_filter
# Out:
#   STATE      1992      1993      1994      1995      1996       1997  \
# 0    CA  296439.8  321495.3  407944.7  216068.7  707110.5   324566.3
# 1    ID  684658.9    7978.2  729029.6  268681.3  896659.9    42902.4
# 2    AK  142717.4  687191.5  261964.9   43962.1  598797.2  2026204.5
#
#        1998          1999        2000  ...        2006          2007  \
# 0  160013.1  8.041234e+05   252676.00  ...  812711.940  1.045292e+06
# 1  151299.3  4.161858e+05  1350786.48  ...  910786.471  2.184656e+06
# 2  120782.1  1.005844e+06   756379.20  ...  254513.800  6.344661e+05
#
#          2008        2009        2010       2011        2012         2013  \
# 0  1430153.60   455350.04   120947.04  192286.92   764766.64   581410.292
# 1   175190.36    23907.91   643868.16  409349.05  1775106.39   740325.500
# 2    92477.60  2949593.97  1137532.67  293004.10   300587.00  1320759.300
#
#         2014        2015
# 0  546878.78   848728.61
# 1  198892.57   791026.11
# 2  233601.28  5136703.76
#
# [3 rows x 25 columns]

# %%
bar_width = 0.25

bars_1995 = cluster_filter[1995]
bars_2000 = cluster_filter[2000]
bars_2005 = cluster_filter[2005]
bars_2010 = cluster_filter[2010]
bars_2015 = cluster_filter[2015]

# %%
position = list(range(len(cluster_filter[1995]))) 
width = 0.10 

fig, ax = plt.subplots(figsize=(12,5))

plt.bar(position, 
        bars_1995, 
        width, 
        alpha=0.5,
        edgecolor='black',
        color='red', 
        label=cluster_filter['STATE'][0]) 
plt.bar([p + width for p in position],
        bars_2000, 
        width, 
        alpha=0.5,
        edgecolor='black',
        color='darkred', 
        label=cluster_filter['STATE'][0]) 
plt.bar([p + width*2 for p in position],
        bars_2005, 
        width, 
        alpha=0.5,
        edgecolor='black',
        color='indianred', 
        # with label the first value in first_name
        label=cluster_filter['STATE'][0]) 
plt.bar([p + width*3 for p in position],
        bars_2010, 
        width, 
        alpha=0.5,
        edgecolor='black',
        color='firebrick', 
        # with label the first value in first_name
        label=cluster_filter['STATE'][0]) 
plt.bar([p + width*4 for p in position],
        bars_2015, 
        width, 
        alpha=0.5,
        edgecolor='black',
        color='crimson', 
        # with label the first value in first_name
        label=cluster_filter['STATE'][0]) 

ax.set_ylabel('Acres Burned')
ax.set_title('Total Acres Burned Across The Years')
ax.set_xticks([p + 1.5 * width for p in position])
ax.set_xticklabels(cluster_filter['STATE'])
plt.legend(['1995', '2000', '2005', '2010', '2015' ], loc='upper left')
plt.grid('y')
plt.show()
plt.savefig("total_acres_burned_top_3_states.png")
