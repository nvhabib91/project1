# %%
from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
from sklearn import datasets
import pandas as pd

# %%
csv = "fire_clean.csv"
fires_pd = pd.read_csv("fire_clean.csv")
fires_pd.head(100)
# Out:
#     FOD_ID SOURCE_SYSTEM        SOURCE_REPORTING_UNIT_NAME  FIRE_YEAR  \
# 0        1   FS-FIRESTAT            Plumas National Forest       2005
# 1        2   FS-FIRESTAT          Eldorado National Forest       2004
# 2        3   FS-FIRESTAT          Eldorado National Forest       2004
# 3        4   FS-FIRESTAT          Eldorado National Forest       2004
# 4        5   FS-FIRESTAT          Eldorado National Forest       2004
# ..     ...           ...                               ...        ...
# 95      97   FS-FIRESTAT  Humboldt-Toiyabe National Forest       2005
# 96      98   FS-FIRESTAT  Humboldt-Toiyabe National Forest       2005
# 97      99   FS-FIRESTAT            Carson National Forest       2005
# 98     100   FS-FIRESTAT            Carson National Forest       2005
# 99     101   FS-FIRESTAT          Kootenai National Forest       2005
#
#    STAT_CAUSE_DESCR  FIRE_SIZE FIRE_SIZE_CLASS   LATITUDE   LONGITUDE STATE
# 0     Miscellaneous       0.10               A  40.036944 -121.005833    CA
# 1         Lightning       0.25               A  38.933056 -120.404444    CA
# 2    Debris Burning       0.10               A  38.984167 -120.735556    CA
# 3         Lightning       0.10               A  38.559167 -119.913333    CA
# 4         Lightning       0.10               A  38.559167 -119.933056    CA
# ..              ...        ...             ...        ...         ...   ...
# 95   Debris Burning       0.10               A  38.700278 -119.840556    CA
# 96            Arson       0.01               A  38.453611 -119.458611    CA
# 97        Lightning       0.10               A  36.669444 -107.253611    NM
# 98        Lightning       0.25               A  36.876389 -107.219167    NM
# 99         Railroad       0.10               A  48.458333 -115.666667    MT
#
# [100 rows x 10 columns]

# %%
average_size = fires_pd.groupby(fires_pd["FIRE_YEAR"]).mean()["FIRE_SIZE"]
years = pd.DataFrame({
    "Average Size of Fire":average_size
})
years
# Out:
#            Average Size of Fire
# FIRE_YEAR
# 1992                  32.364222
# 1993                  35.356208
# 1994                  54.198875
# 1995                  28.676755
# 1996                  79.460604
# 1997                  52.313024
# 1998                  29.414983
# 1999                  68.039342
# 2000                  79.234760
# 2001                  43.009601
# 2002                  89.923580
# 2003                  65.682790
# 2004                 118.855760
# 2005                 109.082041
# 2006                  88.097768
# 2007                  96.946091
# 2008                  63.324652
# 2009                  77.333752
# 2010                  43.728864
# 2011                 106.277026
# 2012                 129.724037
# 2013                  69.350145
# 2014                  54.218860
# 2015                 137.174526

# %%
x_axis = np.arange(1991,2015,1)
y_axis = years
plt.plot(x_axis, y_axis) 
plt.title("Average Size of Fires by Year")
plt.xlabel("Year")
plt.ylabel("Average Size by Acres")
plt.grid()
plt.show()

# %%
total_size = round(fires_pd.groupby(fires_pd["FIRE_YEAR"]).sum()["FIRE_SIZE"],2)
size_years = pd.DataFrame({
    "Total Size of Fire":total_size
})
size_years
# Out:
#            Total Size of Fire
# FIRE_YEAR
# 1992               2199958.00
# 1993               2191696.00
# 1994               4116675.53
# 1995               2049585.06
# 1996               6005155.71
# 1997               3214635.31
# 1998               2011102.40
# 1999               6080199.72
# 2000               7639498.64
# 2001               3724072.30
# 2002               6803258.40
# 2003               4483572.95
# 2004               8234208.17
# 2005               9665105.13
# 2006              10043497.91
# 2007               9265428.73
# 2008               5406532.11
# 2009               6057166.11
# 2010               3493455.22
# 2011               9623597.29
# 2012               9439888.45
# 2013               4492502.41
# 2014               3673490.39
# 2015              10218267.62

# %%
x_axis_2 = np.arange(1991,2015,1)
y_axis_2 = size_years
plt.plot(x_axis_2, y_axis_2) 
plt.title("Total Size of Fires by Year")
plt.xlabel("Year")
plt.ylabel("Total Size by Acres")
plt.grid()
plt.show()

# %%
state = fires_pd["STATE"]
cause = fires_pd["STAT_CAUSE_DESCR"]
causing_fire = cause.value_counts()
causing_fire
# Out:
# Debris Burning       429028
# Miscellaneous        323805
# Arson                281455
# Lightning            278468
# Missing/Undefined    166723
# Equipment Use        147612
# Campfire              76139
# Children              61167
# Smoking               52869
# Railroad              33455
# Powerline             14448
# Fireworks             11500
# Structure              3796
# Name: STAT_CAUSE_DESCR, dtype: int64

# %%
x_values = np.arange(1991,2015,1)
y_values = average_size
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"g")
plt.scatter(x_axis, y_axis, marker="o", facecolors="red", edgecolors="black") 
plt.title("Average Size of Fires by Year")
plt.xlabel("Year")
plt.ylabel("Average Size by Acres")
plt.grid()
plt.show()
print(f"The r-squared is: {rvalue}")
# Out:
# The r-squared is: 0.5874207511728418
